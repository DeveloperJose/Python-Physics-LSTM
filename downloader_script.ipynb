# %% [markdown]
# # Import statements

# %%
import requests
import joblib

import pandas as pd
from tqdm import tqdm

from bs4 import BeautifulSoup
from urllib.error import HTTPError

# %% [markdown]
# # Get all the airfoil IDs from the database
# 1.  Use BeautifulSoup to extract the data from the website

# %%
URL = 'http://airfoiltools.com/search/airfoils'
page = requests.get(URL)
soup = BeautifulSoup(page.content, 'html.parser')

# %% [markdown]
# 2. Parse the data and extract the airfoil internal IDs

# %%
airfoil_table = soup.find('table', class_='listtable')
airfoil_links = airfoil_table.find_all('a')

internal_airfoil_ids = []

for airfoil_tag in airfoil_links:
  link = airfoil_tag['href']
  airfoil_id = link[link.index('airfoil=')+8:]
  internal_airfoil_ids.append(airfoil_id)

print(f"Extracted {len(internal_airfoil_ids)} airfoil internal IDs from the database")
print(internal_airfoil_ids)
# Out:
# -il', 'be50-il', 'be50sm-il', 'boe103-il', 'boe106-il', 'bqm34-il', 'bw3-il', 'c141a-il', 'c141b-il', 'c141c-il', 'c141d-il', 'c141e-il', 'c141f-il', 'c5a-il', 'c5b-il', 'c5c-il', 'c5d-il', 'c5e-il', 'cap21c-il', 'cast102-il', 'ch10sm-il', 'chen-il', 'clarkk-il', 'clarkv-il', 'clarkw-il', 'clarkx-il', 'clarky-il', 'clarkyh-il', 'clarkys-il', 'clarkysm-il', 'clarkz-il', 'clarym15-il', 'clarym18-il', 'coanda1-il', 'coanda2-il', 'coanda3-il', 'cootie-il', 'cp-060-050-gn', 'cp-080-050-gn', 'cp-100-050-gn', 'cp-120-050-gn', 'cp-140-050-gn', 'cp-160-050-gn', 'cp-180-050-gn', 'cr001sm-il', 'cr1-il', 'curtisc72-il', 'dae11-il', 'dae21-il', 'dae31-il', 'dae51-il', 'davis-corrected-il', 'davis-il', 'davissm-il', 'daytonwright6-il', 'daytonwrightt1-il', 'dbln526-il', 'defcnd1-il', 'defcnd2-il', 'defcnd3-il', 'df101-il', 'df102-il', 'dfvlrr4-il', 'dga1138-il', 'dga1182-il', 'dh4009sm-il', 'doa5-il', 'dormoy-il', 'drgnfly-il', 'dsma523a-il', 'dsma523b-il', 'du06-w-200-dt', 'du84132v-il', 'du8608418-il', 'du861372-il', 'e1098-il', 'e1200-il', 'e1210-il', 'e1211-il', 'e1212-il', 'e1212mod-il', 'e1213-il', 'e1214-il', 'e1230-il', 'e1233-il', 'e168-il', 'e169-il', 'e171-il', 'e174-il', 'e176-il', 'e178-il', 'e180-il', 'e182-il', 'e184-il', 'e186-il', 'e193-il', 'e195-il', 'e197-il', 'e201-il', 'e203-il', 'e205-il', 'e207-il', 'e209-il', 'e210-il', 'e211-il', 'e212-il', 'e214-il', 'e216-il', 'e220-il', 'e221-il', 'e222-il', 'e224-il', 'e226-il', 'e228-il', 'e230-il', 'e231-il', 'e266-il', 'e297-il', 'e325-il', 'e326-il', 'e327-il', 'e328-il', 'e329-il', 'e330-il', 'e331-il', 'e332-il', 'e333-il', 'e334-il', 'e335-il', 'e336-il', 'e337-il', 'e338-il', 'e339-il', 'e340-il', 'e341-il', 'e342-il', 'e343-il', 'e344-il', 'e360-il', 'e361-il', 'e374-il', 'e376-il', 'e377-il', 'e377m-il', 'e378-il', 'e379-il', 'e385-il', 'e387-il', 'e392-il', 'e393-il', 'e395-il', 'e396-il', 'e397-il', 'e398-il', 'e399-il', 'e403-il', 'e407-il', 'e417-il', 'e420-il', 'e421-il', 'e422-il', 'e423-il', 'e426-il', 'e428-il', 'e431-il', 'e432-il', 'e433-il', 'e434-il', 'e435-il', 'e471-il', 'e472-il', 'e473-il', 'e474-il', 'e475-il', 'e479-il', 'e485-il', 'e49-il', 'e502-il', 'e520-il', 'e521-il', 'e540-il', 'e541-il', 'e542-il', 'e543-il', 'e544-il', 'e545-il', 'e546-il', 'e547-il', 'e548-il', 'e549-il', 'e550-il', 'e551-il', 'e552-il', 'e553-il', 'e554-il', 'e555-il', 'e556-il', 'e557-il', 'e558-il', 'e559-il', 'e560-il', 'e561-il', 'e562-il', 'e58-il', 'e580-il', 'e582-il', 'e583-il', 'e584-il', 'e585-il', 'e587-il', 'e59-il', 'e591-il', 'e593-il', 'e598-il', 'e603-il', 'e604-il', 'e61-il', 'e62-il', 'e625-il', 'e63-il', 'e635-il', 'e636-il', 'e637-il', 'e638-il', 'e639-il', 'e64-il', 'e642-il', 'e654-il', 'e655-il', 'e656-il', 'e657-il', 'e66-il', 'e662-il', 'e664-il', 'e668-il', 'e67-il', 'e678-il', 'e68-il', 'e682-il', 'e694-il', 'e71-il', 'e715-il', 'e748-il', 'e793-il', 'e817-il', 'e818-il', 'e836-il', 'e837-il', 'e838-il', 'e850-il', 'e851-il', 'e852-il', 'e853-il', 'e854-il', 'e855-il', 'e856-il', 'e857-il', 'e858-il', 'e862-il', 'e863-il', 'e864-il', 'e874-il', 'e904-il', 'e908-il', 'ea61009-il', 'ea61012-il', 'ea81006-il', 'ebambino7-il', 'ec863914-il', 'eh0009-il', 'eh1070-il', 'eh1090-il', 'eh1590-il', 'eh2010-il', 'eh2012-il', 'eh2070-il', 'eh2510-il', 'eh3012-il', 'eiffel10-il', 'eiffel371-il', 'eiffel385-il', 'eiffel428-il', 'eiffel430-il', 'esa40-il', 'falcon-il', 'fauvel-il', 'fg1-il', 'fg2-il', 'fg3-il', 'fg4-il', 'fx049915-il', 'fx05188-il', 'fx05191-il', 'fx057816-il', 'fx05h126-il', 'fx082512-il', 'fx08s176-il', 'fx2-il', 'fx3-il', 'fx38153-il', 'fx60100-il', 'fx601001-il', 'fx60100sm-il', 'fx60126-il', 'fx601261-il', 'fx60157-il', 'fx60160-il', 'fx60177-il', 'fx61140-il', 'fx61147-il', 'fx61163-il', 'fx61168-il', 'fx61184-il', 'fx62k131-il', 'fx62k153-il', 'fx63100-il', 'fx63110-il', 'fx63120-il', 'fx63137-il', 'fx63137sm-il', 'fx63143-il', 'fx63145-il', 'fx63147-il', 'fx63158-il', 'fx6617a2-il', 'fx6617ai-il', 'fx66182-il', 'fx66196v-il', 'fx66a175- ...

# %% [markdown]
# # Download all the Airfoil Selig files

# %%
prev_df = None
lengths = []

for airfoil_type in tqdm(internal_airfoil_ids):
  # This is the template URL used for the selig dat files, we just have to fill in the blanks
  url = f'http://airfoiltools.com/airfoil/seligdatfile?airfoil={airfoil_type}'
  
  try:
    # Try to read the selig file from the website
    df = pd.read_csv(url, skiprows=1, names=['X', 'Y'], sep=' ', skipinitialspace=True)

    # Add the airfoil type information
    df['Airfoil_Type'] = airfoil_type

    # Concatenate with all previous selig coordinates
    prev_df = pd.concat([df, prev_df])

    # Get the length so we can 
    lengths.append(len(df))
  except HTTPError as err:
    print(f"Could not open airfoil selig dat for url {url} because of an exception. {err}")

# Save our results!
prev_df.to_csv('all_airfoil_selig.csv', index=False, compression='gzip')
joblib.dump(lengths, 'all_airfoil_lengths.pkl')

# Get some length statistics
print()
print(f"Max Length = {max(lengths)}, Min Length = {min(lengths)}, Average Length = {sum(lengths)/len(lengths)}")

# Make sure we can read the file
print("=== Test read ===")
print(pd.read_csv('all_airfoil_selig.csv', compression='gzip').head())
# Out:
# 100%|██████████| 1638/1638 [07:29<00:00,  3.64it/s]
#
# Max Length = 260, Min Length = 24, Average Length = 64.43406593406593
# === Test read ===
#          X        Y Airfoil_Type
# 0  1.00000  0.00000     ys930-il
# 1  0.99908  0.00015     ys930-il
# 2  0.99639  0.00070     ys930-il
# 3  0.99210  0.00177     ys930-il
# 4  0.98641  0.00335     ys930-il

# %% [markdown]
# # Download all the polar CSV files and put them into one pandas dataframe

# %%
# This will be the output dataframe with all the CSV files
# It takes around 90 minutes
prev_df = None

# Go through all airfoils in the database and a range of reynolds numbers and ncrits
for airfoil_type in internal_airfoil_ids:
  for reynolds_number in [50000, 100000, 200000, 500000, 1000000]:
    for ncrit in [5, 9]:
      # This is the template URL used for the polar files, we just have to fill in the blanks
      url = f'http://airfoiltools.com/polar/csv?polar=xf-{airfoil_type}-{reynolds_number}'

      # NOTE: Internally ncrit=9 is the default so use the default url without the ncrit={} part
      if ncrit != 9:
        url += '-n' + str(ncrit)

      # Try to read and process the polar file from the url
      try:
        print(f'Downloading and processing CSV for {airfoil_type} with reynolds {reynolds_number} and ncrit {ncrit}')

        # First we skip the useless rows and read the data using pandas
        df = pd.read_csv(url, skiprows=10)

        # Add the airfoil type, reynolds number, and ncrit as columns to the dataframe
        df['Airfoil_Type'] = airfoil_type
        df['Reynolds_Number'] = reynolds_number
        df['Ncrit'] = ncrit

        # Concatenate the new dataframe to the previous dataframes
        prev_df = pd.concat([df, prev_df])
      except HTTPError as err:
        print(f"Could not open airfoil polar csv for url {url} because of an exception. {err}")

prev_df.to_csv('all_airfoil_data.csv', index=False, compression='gzip')
# Out:
# Streaming output truncated to the last 5000 lines.
# Downloading and processing CSV for n24-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n24-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n24-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n2414-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n2414-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n2414-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n2414-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n2414-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n2414-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n2414-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n2414-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n2414-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n2414-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n2415-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n2415-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n2415-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n2415-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n2415-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n2415-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n2415-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n2415-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n2415-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n2415-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n2h15-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n2h15-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n2h15-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n2h15-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n2h15-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n2h15-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n2h15-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n2h15-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n2h15-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n2h15-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n5h10-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n5h10-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n5h10-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n5h10-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n5h10-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n5h10-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n5h10-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n5h10-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n5h10-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n5h10-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n5h15-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n5h15-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n5h15-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n5h15-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n5h15-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n5h15-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n5h15-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n5h15-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n5h15-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n5h15-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n5h20-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n5h20-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n5h20-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n5h20-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n5h20-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n5h20-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n5h20-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n5h20-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n5h20-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n5h20-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63010a-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63010a-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63010a-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63010a-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63010a-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63010a-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63010a-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63010a-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63010a-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63010a-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63012a-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63012a-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63012a-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63012a-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63012a-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63012a-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63012a-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63012a-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63012a-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63012a-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63015a-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63015a-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63015a-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63015a-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63015a-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63015a-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63015a-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63015a-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63015a-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63015a-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63210-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63210-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63210-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63210-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63210-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63210-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63210-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63210-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63210-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63210-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63212-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63212-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63212-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63212-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63212-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63212-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63212-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63212-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63212-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63212-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63215-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63215-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63215-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63215-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63215-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63215-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63215-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63215-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63215-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63215-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63215b-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63215b-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63215b-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63215b-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63215b-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63215b-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63215b-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63215b-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63215b-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63215b-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63412-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63412-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63412-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63412-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63412-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63412-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63412-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63412-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63412-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63412-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n63415-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n63415-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n63415-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n63415-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n63415-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n63415-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n63415-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n63415-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n63415-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n63415-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64008a-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64008a-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64008a-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64008a-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64008a-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64008a-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64008a-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64008a-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64008a-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64008a-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64012-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64012-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64012-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64012-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64012-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64012-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64012-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64012-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64012-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64012-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64012a-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64012a-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64012a-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64012a-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64012a-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64012a-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64012a-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64012a-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64012a-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64012a-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64015-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64015-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64015-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64015-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64015-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64015-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64015-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64015-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64015-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64015-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64015a-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64015a-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64015a-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64015a-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64015a-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64015a-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64015a-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64015a-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64015a-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64015a-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n6409-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n6409-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n6409-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n6409-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n6409-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n6409-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n6409-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n6409-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n6409-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n6409-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64108-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64108-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64108-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64108-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64108-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64108-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64108-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64108-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64108-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64108-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64110-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64110-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64110-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64110-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64110-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64110-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64110-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64110-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64110-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64110-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64212-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64212-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64212-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64212-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64212-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64212-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64212-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64212-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64212-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64212-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64212ma-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64212ma-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64212ma-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64212ma-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64212ma-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64212ma-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64212ma-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64212ma-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64212ma-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64212ma-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64212mb-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64212mb-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64212mb-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64212mb-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64212mb-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64212mb-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64212mb-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64212mb-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64212mb-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64212mb-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n64215-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n64215-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n64215-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n64215-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n64215-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n64215-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n64215-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n64215-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n64215-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n64215-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n66021-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n66021-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n66021-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n66021-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n66021-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n66021-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n66021-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n66021-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n66021-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n66021-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n6h10-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n6h10-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n6h10-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n6h10-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n6h10-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n6h10-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n6h10-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n6h10-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n6h10-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n6h10-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n6h15-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n6h15-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n6h15-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n6h15-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n6h15-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n6h15-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n6h15-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n6h15-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n6h15-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n6h15-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n6h20-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n6h20-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n6h20-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n6h20-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n6h20-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n6h20-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n6h20-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n6h20-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n6h20-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n6h20-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n8h12-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n8h12-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n8h12-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n8h12-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n8h12-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n8h12-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n8h12-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n8h12-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n8h12-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n8h12-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for n9-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for n9-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for n9-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for n9-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for n9-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for n9-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for n9-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for n9-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for n9-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for n9-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0006-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0006-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0006-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0006-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0006-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0006-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0006-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0006-il with reynolds 500000 and ncrit 9
# Could not open airfoil polar csv for url http://airfoiltools.com/polar/csv?polar=xf-naca0006-il-500000 because of an exception. HTTP Error 404: CHttpException
# Downloading and processing CSV for naca0006-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0006-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0008-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0008-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0008-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0008-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0008-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0008-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0008-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0008-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0008-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0008-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca000834-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca000834-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca000834-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca000834-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca000834-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca000834-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca000834-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca000834-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca000834-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca000834-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0010-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0010-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0010-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0010-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0010-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0010-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0010-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0010-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0010-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0010-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001034-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001034-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001034-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001034-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001034-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001034-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001034-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001034-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001034-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001034-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001034a08cli02-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001035-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001035-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001035-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001035-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001035-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001035-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001035-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001035-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001035-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001035-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001064-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001064-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001064-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001064-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001064-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001064-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001064-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001064-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001064-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001064-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001065-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001065-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001065-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001065-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001065-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001065-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001065-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001065-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001065-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001065-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001066-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001066-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001066-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001066-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001066-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001066-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001066-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001066-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001066-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001066-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001234-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001234-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001234-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001234-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001234-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001234-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001234-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001234-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001234-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001234-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001264-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001264-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001264-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001264-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001264-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001264-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001264-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001264-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001264-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001264-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca001264a08cli02-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0012h-sa with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0012h-sa with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0012h-sa with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0012h-sa with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0012h-sa with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0012h-sa with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0012h-sa with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0012h-sa with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0012h-sa with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0012h-sa with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0015-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0015-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0015-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0015-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0015-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0015-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0015-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0015-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0015-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0015-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0018-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0018-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0018-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0018-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0018-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0018-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0018-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0018-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0018-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0018-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0021-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0021-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0021-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0021-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0021-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0021-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0021-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0021-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0021-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0021-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca0024-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca0024-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca0024-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca0024-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca0024-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca0024-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca0024-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca0024-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca0024-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca0024-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca1408-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca1408-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca1408-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca1408-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca1408-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca1408-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca1408-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca1408-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca1408-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca1408-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca1410-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca1410-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca1410-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca1410-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca1410-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca1410-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca1410-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca1410-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca1410-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca1410-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca1412-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca1412-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca1412-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca1412-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca1412-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca1412-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca1412-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca1412-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca1412-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca1412-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca16006-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca16006-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca16006-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca16006-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca16006-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca16006-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca16006-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca16006-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca16006-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca16006-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca16009-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca16009-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca16009-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca16009-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca16009-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca16009-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca16009-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca16009-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca16009-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca16009-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca16012-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca16012-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca16012-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca16012-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca16012-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca16012-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca16012-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca16012-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca16012-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca16012-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca16015-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca16015-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca16015-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca16015-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca16015-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca16015-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca16015-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca16015-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca16015-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca16015-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca16018-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca16018-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca16018-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca16018-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca16018-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca16018-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca16018-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for naca16018-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for naca16018-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for naca16018-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for naca16021-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for naca16021-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for naca16021-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for naca16021-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for naca16021-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for naca16021-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for naca16021-il with reynolds 500000 and ncrit 5
# ...
# Downloading and processing CSV for v43012-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for v43012-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for v43012-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for v43012-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for v43012-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for v43012-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for v43012-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for v43012-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for v43015-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for v43015-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for v43015-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for v43015-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for v43015-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for v43015-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for v43015-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for v43015-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for v43015-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for v43015-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr1-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr1-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr1-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr1-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr1-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr1-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr1-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr1-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr1-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr1-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr11x-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr11x-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr11x-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr11x-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr11x-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr11x-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr11x-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr11x-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr11x-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr11x-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr12-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr12-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr12-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr12-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr12-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr12-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr12-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr12-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr12-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr12-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr13-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr13-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr13-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr13-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr13-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr13-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr13-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr13-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr13-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr13-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr14-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr14-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr14-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr14-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr14-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr14-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr14-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr14-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr14-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr14-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr15-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr15-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr15-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr15-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr15-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr15-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr15-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr15-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr15-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr15-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr5-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr5-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr5-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr5-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr5-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr5-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr5-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr5-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr5-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr5-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr7-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr7-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr7-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr7-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr7-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr7-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr7-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr7-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr7-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr7-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr7b-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr7b-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr7b-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr7b-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr7b-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr7b-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr7b-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr7b-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr7b-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr7b-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr8-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr8-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr8-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr8-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr8-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr8-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr8-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr8-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr8-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr8-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr8b-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr8b-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr8b-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr8b-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr8b-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr8b-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr8b-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr8b-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr8b-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr8b-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for vr9-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for vr9-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for vr9-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for vr9-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for vr9-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for vr9-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for vr9-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for vr9-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for vr9-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for vr9-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for waspsm-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for waspsm-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for waspsm-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for waspsm-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for waspsm-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for waspsm-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for waspsm-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for waspsm-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for waspsm-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for waspsm-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for wb13535sm-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for wb13535sm-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for wb13535sm-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for wb13535sm-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for wb13535sm-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for wb13535sm-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for wb13535sm-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for wb13535sm-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for wb13535sm-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for wb13535sm-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for wb140-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for wb140-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for wb140-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for wb140-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for wb140-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for wb140-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for wb140-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for wb140-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for wb140-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for wb140-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for whitcomb-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for whitcomb-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for whitcomb-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for whitcomb-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for whitcomb-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for whitcomb-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for whitcomb-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for whitcomb-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for whitcomb-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for whitcomb-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for ys900-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for ys900-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for ys900-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for ys900-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for ys900-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for ys900-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for ys900-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for ys900-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for ys900-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for ys900-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for ys915-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for ys915-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for ys915-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for ys915-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for ys915-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for ys915-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for ys915-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for ys915-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for ys915-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for ys915-il with reynolds 1000000 and ncrit 9
# Downloading and processing CSV for ys930-il with reynolds 50000 and ncrit 5
# Downloading and processing CSV for ys930-il with reynolds 50000 and ncrit 9
# Downloading and processing CSV for ys930-il with reynolds 100000 and ncrit 5
# Downloading and processing CSV for ys930-il with reynolds 100000 and ncrit 9
# Downloading and processing CSV for ys930-il with reynolds 200000 and ncrit 5
# Downloading and processing CSV for ys930-il with reynolds 200000 and ncrit 9
# Downloading and processing CSV for ys930-il with reynolds 500000 and ncrit 5
# Downloading and processing CSV for ys930-il with reynolds 500000 and ncrit 9
# Downloading and processing CSV for ys930-il with reynolds 1000000 and ncrit 5
# Downloading and processing CSV for ys930-il with reynolds 1000000 and ncrit 9

# %%
print(len(prev_df))
# Out:
# 1692967
